# %% [markdown]
# <a href="https://colab.research.google.com/github/nansu2026/CA2/blob/main/Dissertation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# establishes reproducibility
import os

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

import random
import numpy as np
import tensorflow as tf

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Force CPU-only execution — GPU/cuDNN's LSTM kernels aren't fully deterministic
# even with a fixed seed, which was causing CV results to vary run-to-run
tf.config.set_visible_devices([], 'GPU')
print("Visible GPUs:", tf.config.list_physical_devices('GPU'))

# %%
# Download the EirGrid dataset directly from GitHub
import urllib.request, zipfile, os

url = "https://github.com/Daniel-Parke/EirGrid_Data_Download/archive/refs/heads/main.zip"
zip_filename = "EirGrid_Data_Download-main.zip"
extract_to = "/content/extracted"

if not os.path.exists(zip_filename):
    print("Downloading dataset from GitHub...")
    urllib.request.urlretrieve(url, zip_filename)
    print("Download complete.")

if not os.path.exists(extract_to):
    with zipfile.ZipFile(zip_filename, 'r') as z:
        z.extractall(extract_to)
    print("Extracted.")
else:
    print("Already extracted, skipping.")

roi_path = os.path.join(extract_to, "EirGrid_Data_Download-main", "Downloaded_Data", "ROI")
print(os.listdir(roi_path)[:5])
# Out:
# ...
# Download complete.
# Extracted.
# ['ROI_generationactual_14_Eirgrid.csv', 'ROI_co2emission_18_Eirgrid.csv', 'ROI_co2emission_15_Eirgrid.csv', 'ROI_interconnection_19_Eirgrid.csv', 'ROI_co2intensity_24_Eirgrid.csv']

# %%
# Preview the raw file structure :- no header row, 4 columns: DateTime, Type, Region, Value
import pandas as pd
import os

raw = pd.read_csv(os.path.join(roi_path, "ROI_demandactual_14_Eirgrid.csv"), header=None, nrows=15)
print(raw.to_string())
# Out:
#                        0              1    2       3
# 0   01-Jan-2014 00:00:00  SYSTEM_DEMAND  ROI  2899.0
# 1   01-Jan-2014 00:15:00  SYSTEM_DEMAND  ROI  2869.0
# 2   01-Jan-2014 00:30:00  SYSTEM_DEMAND  ROI  2826.0
# 3   01-Jan-2014 00:45:00  SYSTEM_DEMAND  ROI  2787.0
# 4   01-Jan-2014 01:00:00  SYSTEM_DEMAND  ROI  2724.0
# 5   01-Jan-2014 01:15:00  SYSTEM_DEMAND  ROI  2686.0
# 6   01-Jan-2014 01:30:00  SYSTEM_DEMAND  ROI  2597.0
# 7   01-Jan-2014 01:45:00  SYSTEM_DEMAND  ROI  2543.0
# 8   01-Jan-2014 02:00:00  SYSTEM_DEMAND  ROI  2483.0
# 9   01-Jan-2014 02:15:00  SYSTEM_DEMAND  ROI  2437.0
# 10  01-Jan-2014 02:30:00  SYSTEM_DEMAND  ROI  2392.0
# 11  01-Jan-2014 02:45:00  SYSTEM_DEMAND  ROI  2341.0
# 12  01-Jan-2014 03:00:00  SYSTEM_DEMAND  ROI  2303.0
# 13  01-Jan-2014 03:15:00  SYSTEM_DEMAND  ROI  2273.0
# 14  01-Jan-2014 03:30:00  SYSTEM_DEMAND  ROI  2227.0

# %%
# Merge all 11 yearly ROI demand files into a 15-minute resolution dataset with calendar features
import pandas as pd
import glob
import os

all_dfs = []
for f in sorted(glob.glob(os.path.join(roi_path, "ROI_demandactual_*.csv"))):
    temp = pd.read_csv(f, header=None, names=['DateTime', 'Type', 'Region', 'SYSTEM_DEMAND_MW'])
    all_dfs.append(temp)

df = pd.concat(all_dfs, ignore_index=True)
df['DateTime'] = pd.to_datetime(df['DateTime'], dayfirst=True)
df['SYSTEM_DEMAND_MW'] = pd.to_numeric(df['SYSTEM_DEMAND_MW'], errors='coerce')
df = df.sort_values('DateTime').reset_index(drop=True)

# Add time features
df['Year']      = df['DateTime'].dt.year
df['Month']     = df['DateTime'].dt.month
df['Day']       = df['DateTime'].dt.day
df['DayOfWeek'] = df['DateTime'].dt.dayofweek
df['Hour']      = df['DateTime'].dt.hour
df['Minute']    = df['DateTime'].dt.minute
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# Fill missing
# df['SYSTEM_DEMAND_MW'] = df['SYSTEM_DEMAND_MW'].interpolate(method='linear')

# Remove missing values
print("Nulls before drop:", df['SYSTEM_DEMAND_MW'].isnull().sum())
df = df.dropna(subset=['SYSTEM_DEMAND_MW']).reset_index(drop=True)

# Truncate dataset to end 19 Feb 2024
CUTOFF_DATE = '2024-02-19'
rows_before_cutoff = len(df)
df = df[df['DateTime'] <= CUTOFF_DATE].reset_index(drop=True)
print(f"Rows removed by date cutoff: {rows_before_cutoff - len(df):,}")
print(f"Dataset now spans: {df['DateTime'].min()} to {df['DateTime'].max()}")

print(f"Total rows: {len(df):,}")
print(df.head(10).to_string())
print(df.describe())

# Download
df.to_csv("EirGrid_Ireland_15min_2014_2024.csv", index=False)
#from google.colab import files
#files.download("EirGrid_Ireland_15min_2014_2024.csv")
# Out:
# Nulls before drop: 31487
# Rows removed by date cutoff: 60
# Dataset now spans: 2014-01-01 00:00:00 to 2024-02-19 00:00:00
# Total rows: 365,797
#              DateTime           Type Region  SYSTEM_DEMAND_MW  Year  Month  Day  DayOfWeek  Hour  Minute  IsWeekend
# 0 2014-01-01 00:00:00  SYSTEM_DEMAND    ROI            2899.0  2014      1    1          2     0       0          0
# 1 2014-01-01 00:15:00  SYSTEM_DEMAND    ROI            2869.0  2014      1    1          2     0      15          0
# 2 2014-01-01 00:30:00  SYSTEM_DEMAND    ROI            2826.0  2014      1    1          2     0      30          0
# 3 2014-01-01 00:45:00  SYSTEM_DEMAND    ROI            2787.0  2014      1    1          2     0      45          0
# 4 2014-01-01 01:00:00  SYSTEM_DEMAND    ROI            2724.0  2014      1    1          2     1       0          0
# 5 2014-01-01 01:15:00  SYSTEM_DEMAND    ROI            2686.0  2014      1    1          2     1      15          0
# ...

# %%
# Resample the merged data into hourly averages and run data-quality checks
import pandas as pd
import glob
import os

# Combine all files
all_dfs = []
for f in sorted(glob.glob(os.path.join(roi_path, "ROI_demandactual_*.csv"))):
    temp = pd.read_csv(f, header=None, names=['DateTime', 'Type', 'Region', 'SYSTEM_DEMAND_MW'])
    all_dfs.append(temp)

df = pd.concat(all_dfs, ignore_index=True)

# Clean & convert
df['DateTime'] = pd.to_datetime(df['DateTime'], dayfirst=True)
df['SYSTEM_DEMAND_MW'] = pd.to_numeric(df['SYSTEM_DEMAND_MW'], errors='coerce')
df = df.sort_values('DateTime').reset_index(drop=True)

# Resample to hourly
df_hourly = df.set_index('DateTime').resample('H')['SYSTEM_DEMAND_MW'].mean().reset_index()

# Add time features
df_hourly['Year']      = df_hourly['DateTime'].dt.year
df_hourly['Month']     = df_hourly['DateTime'].dt.month
df_hourly['Day']       = df_hourly['DateTime'].dt.day
df_hourly['DayOfWeek'] = df_hourly['DateTime'].dt.dayofweek  # 0=Mon, 6=Sun
df_hourly['Hour']      = df_hourly['DateTime'].dt.hour
df_hourly['IsWeekend'] = df_hourly['DayOfWeek'].isin([5, 6]).astype(int)

# Handle missing values
#df_hourly['SYSTEM_DEMAND_MW'] = df_hourly['SYSTEM_DEMAND_MW'].interpolate(method='linear')

# Remove missing values
print("Nulls before drop:", df_hourly['SYSTEM_DEMAND_MW'].isnull().sum())
df_hourly = df_hourly.dropna(subset=['SYSTEM_DEMAND_MW']).reset_index(drop=True)

# Truncate dataset to end 19 Feb 2024
CUTOFF_DATE = '2024-02-19'
rows_before_cutoff = len(df_hourly)
df_hourly = df_hourly[df_hourly['DateTime'] <= CUTOFF_DATE].reset_index(drop=True)
print(f"Rows removed by date cutoff: {rows_before_cutoff - len(df_hourly):,}")
print(f"Dataset now spans: {df_hourly['DateTime'].min()} to {df_hourly['DateTime'].max()}")

# Preview
print("=== COLUMN NAMES (ATTRIBUTES) ===")
print(df_hourly.columns.tolist())

print(f"\n=== DATASET SHAPE ===")
print(f"Rows: {len(df_hourly):,}  |  Columns: {df_hourly.shape[1]}")

print(f"\n=== DATE RANGE ===")
print(f"{df_hourly['DateTime'].min()} → {df_hourly['DateTime'].max()}")

print(f"\n=== FIRST 10 ROWS ===")
print(df_hourly.head(10).to_string())

print(f"\n=== STATS FOR ALL COLUMNS ===")
print(df_hourly.describe())

# Data Quality Checks

print("="*50)
print("DATA QUALITY CHECK")
print("="*50)

print("\nMissing Values:")
print(df_hourly.isnull().sum())

print("\nDuplicate Rows:")
print(df_hourly.duplicated().sum())

print("\nDuplicate DateTime Values:")
print(df_hourly['DateTime'].duplicated().sum())

print("\nData Types:")
print(df_hourly.dtypes)

print("\nSummary Statistics:")
print(df_hourly.describe())

# Download as CSV
df_hourly.to_csv("EirGrid_Ireland_Demand_2014_2024_Hourly.csv", index=False)
print("\n✅ File saved! Now downloading...")

#from google.colab import files
#files.download("EirGrid_Ireland_Demand_2014_2024_Hourly.csv")
# Out:
# /tmp/ipykernel_711/2840584598.py:20: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_hourly = df.set_index('DateTime').resample('H')['SYSTEM_DEMAND_MW'].mean().reset_index()
# Nulls before drop: 7645
# Rows removed by date cutoff: 15
# Dataset now spans: 2014-01-01 00:00:00 to 2024-02-19 00:00:00
# === COLUMN NAMES (ATTRIBUTES) ===
# ['DateTime', 'SYSTEM_DEMAND_MW', 'Year', 'Month', 'Day', 'DayOfWeek', 'Hour', 'IsWeekend']
#
# === DATASET SHAPE ===
# Rows: 88,794  |  Columns: 8
#
# === DATE RANGE ===
# 2014-01-01 00:00:00 → 2024-02-19 00:00:00
#
# === FIRST 10 ROWS ===
#              DateTime  SYSTEM_DEMAND_MW  Year  Month  Day  DayOfWeek  Hour  IsWeekend
# 0 2014-01-01 00:00:00           2845.25  2014      1    1          2     0          0
# 1 2014-01-01 01:00:00           2637.50  2014      1    1          2     1          0
# 2 2014-01-01 02:00:00           2413.25  2014      1    1          2     2          0
# ...

# %%
# Standardize the working variable name to 'df' for all following cells
df = df_hourly.copy()
print(f"Rows: {len(df):,}   |   Columns: {df.shape[1]}")
df.head()
# Out:
# Rows: 88,794   |   Columns: 8
#              DateTime  SYSTEM_DEMAND_MW  Year  Month  Day  DayOfWeek  Hour  \
# 0 2014-01-01 00:00:00           2845.25  2014      1    1          2     0
# 1 2014-01-01 01:00:00           2637.50  2014      1    1          2     1
# 2 2014-01-01 02:00:00           2413.25  2014      1    1          2     2
# 3 2014-01-01 03:00:00           2251.50  2014      1    1          2     3
# 4 2014-01-01 04:00:00           2132.25  2014      1    1          2     4
#
#    IsWeekend
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# Import libraries used for modeling, evaluation, and plotting
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

import warnings
warnings.filterwarnings("ignore")

plt.style.use("ggplot")
sns.set_theme(style="whitegrid")

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
# Print summary statistics for the demand column
print(df['SYSTEM_DEMAND_MW'].describe())
# Out:
# count    88794.000000
# mean      3314.668623
# std        653.240305
# min       1684.250000
# 25%       2817.250000
# 50%       3354.000000
# 75%       3785.000000
# max       5517.750000
# Name: SYSTEM_DEMAND_MW, dtype: float64

# %%
# Plot average demand by hour, day of week, month, and year
fig, axes = plt.subplots(2, 2, figsize=(14, 9))

hourly_avg = df.groupby('Hour')['SYSTEM_DEMAND_MW'].mean()
axes[0,0].plot(hourly_avg.index, hourly_avg.values, marker='o', color='#1E2761')
axes[0,0].set_title('Average Demand by Hour of Day')
axes[0,0].set_xlabel('Hour'); axes[0,0].set_ylabel('Demand (MW)')

dow_avg = df.groupby('DayOfWeek')['SYSTEM_DEMAND_MW'].mean()
axes[0,1].bar(['Mon','Tue','Wed','Thu','Fri','Sat','Sun'], dow_avg.values, color='#1E2761')
axes[0,1].set_title('Average Demand by Day of Week')
axes[0,1].set_ylabel('Demand (MW)')

month_avg = df.groupby('Month')['SYSTEM_DEMAND_MW'].mean()
axes[1,0].plot(month_avg.index, month_avg.values, marker='o', color='#B85042')
axes[1,0].set_title('Average Demand by Month (Seasonality)')
axes[1,0].set_xlabel('Month'); axes[1,0].set_ylabel('Demand (MW)')

year_avg = df.groupby('Year')['SYSTEM_DEMAND_MW'].mean()
axes[1,1].plot(year_avg.index, year_avg.values, marker='o', color='#028090')
axes[1,1].set_title('Average Demand by Year (Long-Term Trend)')
axes[1,1].set_xlabel('Year'); axes[1,1].set_ylabel('Demand (MW)')

plt.tight_layout()
plt.show()

# %%
# Plot the full daily mean demand time series, 2014–2024
daily = df.set_index('DateTime')['SYSTEM_DEMAND_MW'].resample('D').mean()

plt.figure(figsize=(15, 4))
plt.plot(daily.index, daily.values, color='#1E2761', linewidth=0.8)
plt.title('Daily Mean Electricity Demand — Ireland (2014–2024)')
plt.xlabel('Date'); plt.ylabel('Demand (MW)')
plt.tight_layout()
plt.show()

# %%
# Split data chronologically: 80% train, 20% test (time series)
SPLIT_RATIO = 0.8
split_idx = int(len(df) * SPLIT_RATIO)
SPLIT_DATE = df.loc[split_idx, 'DateTime']

train_df = df.iloc[:split_idx].reset_index(drop=True)
test_df  = df.iloc[split_idx:].reset_index(drop=True)

print(f"Split date: {SPLIT_DATE}")
print(f"Train: {len(train_df):,} rows ({len(train_df)/len(df)*100:.1f}%)  ({train_df['DateTime'].min()} -> {train_df['DateTime'].max()})")
print(f"Test:  {len(test_df):,} rows ({len(test_df)/len(df)*100:.1f}%)  ({test_df['DateTime'].min()} -> {test_df['DateTime'].max()})")

def evaluate_forecast(y_true, y_pred, model_name):
    mae  = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((np.array(y_true) - np.array(y_pred)) / np.array(y_true))) * 100
    print(f"{model_name:15s} | MAE: {mae:8.2f} MW | RMSE: {rmse:8.2f} MW | MAPE: {mape:6.2f}%")
    return {"Model": model_name, "MAE": mae, "RMSE": rmse, "MAPE": mape}

results = []
# Out:
# Split date: 2022-02-08 14:00:00
# Train: 71,035 rows (80.0%)  (2014-01-01 00:00:00 -> 2022-02-08 13:00:00)
# Test:  17,759 rows (20.0%)  (2022-02-08 14:00:00 -> 2024-02-19 00:00:00)

# %%
# Define a reusable time-series cross-validation runner, shared across ARIMA, Random Forest, and LSTM (defines the evaluation framework)
from sklearn.model_selection import TimeSeriesSplit

def run_timeseries_cv(data, fold_fn, label, n_splits=5):
    tscv = TimeSeriesSplit(n_splits=n_splits)
    cv_results = []

    for fold, (train_idx, test_idx) in enumerate(tscv.split(data), start=1):
        train_fold = data.iloc[train_idx].reset_index(drop=True)
        test_fold  = data.iloc[test_idx].reset_index(drop=True)

        y_true, y_pred = fold_fn(train_fold, test_fold)

        mae  = mean_absolute_error(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        mape = np.mean(np.abs((np.array(y_true) - np.array(y_pred)) / np.array(y_true))) * 100

        print(f"[{label}] Fold {fold}: Train {len(train_fold):,} | Test {len(test_fold):,} "
              f"| MAE {mae:.2f} MW | RMSE {rmse:.2f} MW | MAPE {mape:.2f}%")

        cv_results.append({"Model": label, "Fold": fold, "MAE": mae, "RMSE": rmse, "MAPE": mape})

    cv_df = pd.DataFrame(cv_results)
    print(f"\n=== {label} CV Summary ===")
    print(f"MAE  mean: {cv_df['MAE'].mean():.2f}  std: {cv_df['MAE'].std():.2f}")
    print(f"RMSE mean: {cv_df['RMSE'].mean():.2f}  std: {cv_df['RMSE'].std():.2f}")
    print(f"MAPE mean: {cv_df['MAPE'].mean():.2f}%  std: {cv_df['MAPE'].std():.2f}%")
    return cv_df

# %%
# Install pmdarima for automatic ARIMA order selection
# !pip install pmdarima -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.9/688.9 kB 38.8 MB/s eta 0:00:00

# %%
# Run the Augmented Dickey-Fuller test to check stationarity
from statsmodels.tsa.stattools import adfuller

series_full = train_df.set_index('DateTime')['SYSTEM_DEMAND_MW']

adf_result = adfuller(series_full)
print(f"ADF Statistic: {adf_result[0]:.4f}")
print(f"p-value:       {adf_result[1]:.4f}")
if adf_result[1] < 0.05:
    print("=> Series is stationary (reject H0).")
else:
    print("=> Series is NOT stationary — differencing will be applied by auto_arima (d>0).")
# Out:
# ADF Statistic: -13.0447
# p-value:       0.0000
# => Series is stationary (reject H0).

# %%
# Use auto_arima to search for the best (p,d,q) order
import pmdarima as pm

ARIMA_WINDOW_HOURS = 24 * 365 * 2
arima_train_series = series_full.iloc[-ARIMA_WINDOW_HOURS:]

print(f"Selecting ARIMA order on {len(arima_train_series):,} recent training hours...")

auto_model = pm.auto_arima(
    arima_train_series,
    start_p=0, start_q=0, max_p=5, max_q=5,
    d=None,
    seasonal=False,
    trace=True,
    error_action='ignore',
    suppress_warnings=True,
    stepwise=True
)

print(auto_model.summary())
order = auto_model.order
print(f"\nSelected order (p,d,q): {order}")
# Out:
# Selecting ARIMA order on 17,520 recent training hours...
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=232764.724, Time=0.48 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=217014.428, Time=1.90 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=219360.864, Time=10.41 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=232762.725, Time=0.35 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=213968.432, Time=3.29 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=213692.103, Time=4.75 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=213522.592, Time=4.80 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=213122.915, Time=4.01 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=45.04 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=43.08 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : AIC=213120.915, Time=1.22 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=213520.592, Time=1.07 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=inf, Time=15.76 sec
# ...

# %%
# Fit the final ARIMA model and forecast the test period blind (multi-step, no peeking)
from statsmodels.tsa.arima.model import ARIMA

print("Fitting final ARIMA model — this may take a few minutes...")
arima_final = ARIMA(arima_train_series, order=order)
arima_fit = arima_final.fit()

n_forecast = len(test_df)
arima_forecast = arima_fit.forecast(steps=n_forecast)

test_df['ARIMA_Pred'] = arima_forecast.values
results.append(evaluate_forecast(test_df['SYSTEM_DEMAND_MW'], test_df['ARIMA_Pred'], "ARIMA"))
# Out:
# Fitting final ARIMA model — this may take a few minutes...
# /usr/local/lib/python3.13/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.13/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.13/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
# Plot ARIMA's forecast against actual demand for the first two weeks of the test set
plot_slice = test_df.iloc[:24*14]

plt.figure(figsize=(14, 4))
plt.plot(plot_slice['DateTime'], plot_slice['SYSTEM_DEMAND_MW'], label='Actual', color='black', linewidth=1)
plt.plot(plot_slice['DateTime'], plot_slice['ARIMA_Pred'], label='ARIMA Forecast', color='#B85042', linewidth=1)
plt.title('ARIMA — Actual vs Predicted (First 2 Weeks of Test Set)')
plt.xlabel('Date'); plt.ylabel('Demand (MW)'); plt.legend()
plt.tight_layout()
plt.show()

# %%
# Generate ARIMA walk-forward, one-step-ahead predictions using the true previous value each step
# Build one continuous series across train + test
full_series = df.set_index('DateTime')['SYSTEM_DEMAND_MW']

n_train = len(train_df)
n_total = len(full_series)

# Re-apply the already-fitted ARIMA(5,1,0) parameters to the full series (no re-estimation, refit=False)
arima_walkforward = arima_fit.apply(full_series, refit=False)

# One-step-ahead predictions across the whole test period:
# dynamic=False means at every hour, the model uses the TRUE previous value, not its own earlier guess
pred = arima_walkforward.get_prediction(start=n_train, end=n_total - 1, dynamic=False)
arima_pred_wf = pred.predicted_mean.values

test_df['ARIMA_Pred_WF'] = arima_pred_wf

# Keep the original blind forecast result for discussion, but label it clearly
results[0]['Model'] = "ARIMA (Blind Multi-Step)"

arima_train_fitted = arima_fit.fittedvalues
results.append(evaluate_forecast(arima_train_series, arima_train_fitted, "ARIMA - Train"))
results.append(evaluate_forecast(test_df['SYSTEM_DEMAND_MW'], test_df['ARIMA_Pred_WF'], "ARIMA (Walk-Forward)"))
# Out:
# /usr/local/lib/python3.13/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.13/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.13/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ARIMA - Train   | MAE:    75.00 MW | RMSE:   109.85 MW | MAPE:   2.15%
# ARIMA (Walk-Forward) | MAE:    69.08 MW | RMSE:    97.43 MW | MAPE:   1.86%

# %%
# ARIMA fold function for cross-validation: fits a fresh (2,1,2) model per fold and forecasts blind, testing how ARIMA generalises across the decade
def arima_fold_fn(train_fold, test_fold):
    order = (2, 1, 2)  # or reuse the order from your auto_arima search
    model = ARIMA(train_fold['SYSTEM_DEMAND_MW'], order=order).fit()
    forecast = model.forecast(steps=len(test_fold))
    return test_fold['SYSTEM_DEMAND_MW'].values, forecast.values

arima_cv_df = run_timeseries_cv(df, arima_fold_fn, label="ARIMA", n_splits=3)
# Out:
# [ARIMA] Fold 1: Train 22,200 | Test 22,198 | MAE 600.63 MW | RMSE 712.89 MW | MAPE 17.98%
# [ARIMA] Fold 2: Train 44,398 | Test 22,198 | MAE 530.21 MW | RMSE 650.27 MW | MAPE 17.78%
# [ARIMA] Fold 3: Train 66,596 | Test 22,198 | MAE 621.96 MW | RMSE 750.33 MW | MAPE 16.02%
#
# === ARIMA CV Summary ===
# MAE  mean: 584.27  std: 48.01
# RMSE mean: 704.50  std: 50.55
# MAPE mean: 17.26%  std: 1.08%

# %%
# Build lag features (1h, 24h, 168h) since Random Forest has no built-in sense of time
def add_lag_features(data):
    data = data.copy()
    data['Lag_1h']   = data['SYSTEM_DEMAND_MW'].shift(1)
    data['Lag_24h']  = data['SYSTEM_DEMAND_MW'].shift(24)
    data['Lag_168h'] = data['SYSTEM_DEMAND_MW'].shift(168)  # same hour, previous week
    return data

df_lagged = add_lag_features(df)
df_lagged = df_lagged.dropna().reset_index(drop=True)

train_lagged = df_lagged[df_lagged['DateTime'] < SPLIT_DATE].reset_index(drop=True)
test_lagged  = df_lagged[df_lagged['DateTime'] >= SPLIT_DATE].reset_index(drop=True)

CALENDAR_FEATURES = ['Hour', 'DayOfWeek', 'IsWeekend', 'Month', 'Day', 'Year']
LAG_FEATURES      = ['Lag_1h', 'Lag_24h', 'Lag_168h']
TARGET            = 'SYSTEM_DEMAND_MW'

print(f"Train rows: {len(train_lagged):,}  |  Test rows: {len(test_lagged):,}")
# Out:
# Train rows: 70,867  |  Test rows: 17,759

# %%
# Train a baseline Random Forest using calendar features only
from sklearn.ensemble import RandomForestRegressor

X_train_cal = train_lagged[CALENDAR_FEATURES]
y_train_cal = train_lagged[TARGET]
X_test_cal  = test_lagged[CALENDAR_FEATURES]
y_test_cal  = test_lagged[TARGET]

rf_baseline = RandomForestRegressor(n_estimators=200, max_depth=15, random_state=42, n_jobs=-1)
rf_baseline.fit(X_train_cal, y_train_cal)
rf_baseline_pred = rf_baseline.predict(X_test_cal)

rf_baseline_train_pred = rf_baseline.predict(X_train_cal)
results.append(evaluate_forecast(y_train_cal, rf_baseline_train_pred, "RF (Calendar) - Train"))
results.append(evaluate_forecast(y_test_cal, rf_baseline_pred, "RF (Calendar) - Test"))
# Out:
# RF (Calendar) - Train | MAE:    41.59 MW | RMSE:    57.41 MW | MAPE:   1.30%
# RF (Calendar) - Test | MAE:   150.87 MW | RMSE:   192.75 MW | MAPE:   4.16%

# %%
# Train Random Forest with calendar + lag features and compare against the baseline
FEATURES = CALENDAR_FEATURES + LAG_FEATURES

X_train = train_lagged[FEATURES]
y_train = train_lagged[TARGET]
X_test  = test_lagged[FEATURES]
y_test  = test_lagged[TARGET]

rf_full = RandomForestRegressor(n_estimators=300, max_depth=20, random_state=42, n_jobs=-1)
rf_full.fit(X_train, y_train)
rf_full_pred = rf_full.predict(X_test)

rf_full_train_pred = rf_full.predict(X_train)
results.append(evaluate_forecast(y_train, rf_full_train_pred, "RF (Cal+Lag) - Train"))
results.append(evaluate_forecast(y_test, rf_full_pred, "RF (Cal+Lag) - Test"))
test_lagged['RF_Pred'] = rf_full_pred

print("\nComparison: adding lag features to Random Forest")
print(f"  Calendar only : MAE {mean_absolute_error(y_test_cal, rf_baseline_pred):.2f} MW")
print(f"  Calendar+Lag  : MAE {mean_absolute_error(y_test, rf_full_pred):.2f} MW")

# %%
# Random split comparison for Random Forest
from sklearn.model_selection import train_test_split

train_random, test_random = train_test_split(df_lagged, test_size=0.2, shuffle=True, random_state=42)
train_random = train_random.reset_index(drop=True)
test_random  = test_random.reset_index(drop=True)

X_train_rand = train_random[FEATURES]
y_train_rand = train_random[TARGET]
X_test_rand  = test_random[FEATURES]
y_test_rand  = test_random[TARGET]

rf_random = RandomForestRegressor(n_estimators=300, max_depth=20, random_state=42, n_jobs=-1)
rf_random.fit(X_train_rand, y_train_rand)
rf_random_pred = rf_random.predict(X_test_rand)

results.append(evaluate_forecast(y_test_rand, rf_random_pred, "RF (Cal+Lag) - Random Split"))

# %%
# Fold function for Random Forest — used by run_timeseries_cv
def rf_fold_fn(train_fold, test_fold):
    X_train, y_train = train_fold[FEATURES], train_fold[TARGET]
    X_test,  y_test  = test_fold[FEATURES],  test_fold[TARGET]
    model = RandomForestRegressor(n_estimators=300, max_depth=20, random_state=42, n_jobs=-1)
    model.fit(X_train, y_train)
    return y_test, model.predict(X_test)

rf_cv_df = run_timeseries_cv(df_lagged, rf_fold_fn, label="Random Forest", n_splits=5)

# %%
# Scale demand values and build 24-hour sliding-window sequences for the LSTM
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input
from tensorflow.keras.callbacks import EarlyStopping

WINDOW = 24  # past 24 hours used to predict the next hour

# Fit scaler on TRAIN ONLY to avoid leaking test-set information
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_df[['SYSTEM_DEMAND_MW']])
test_scaled  = scaler.transform(test_df[['SYSTEM_DEMAND_MW']])

def create_sequences(data, window):
    X, y = [], []
    for i in range(window, len(data)):
        X.append(data[i-window:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

combined_scaled = np.concatenate([train_scaled[-WINDOW:], test_scaled])

X_train_lstm, y_train_lstm = create_sequences(train_scaled, WINDOW)
X_test_lstm,  y_test_lstm  = create_sequences(combined_scaled, WINDOW)

X_train_lstm = X_train_lstm.reshape((X_train_lstm.shape[0], X_train_lstm.shape[1], 1))
X_test_lstm  = X_test_lstm.reshape((X_test_lstm.shape[0], X_test_lstm.shape[1], 1))

print(f"X_train_lstm: {X_train_lstm.shape}  |  X_test_lstm: {X_test_lstm.shape}")

# %%
# Define the LSTM model: one LSTM(64) layer feeding into a single output neuron
lstm_model = Sequential([
    Input(shape=(WINDOW, 1)),
    LSTM(64, activation='tanh'),
    Dense(1)
])

lstm_model.compile(optimizer='adam', loss='mse')
lstm_model.summary()

# %%
# Check GPU availability and train the LSTM with early stopping
import tensorflow as tf
print("GPUs available:", tf.config.list_physical_devices('GPU'))
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = lstm_model.fit(
    X_train_lstm, y_train_lstm,
    validation_split=0.1,
    epochs=30,
    batch_size=256,
    callbacks=[early_stop],
    verbose=1
)

# %%
# Generate LSTM predictions, inverse-transform to MW, and score against actual demand
lstm_pred_scaled = lstm_model.predict(X_test_lstm)
lstm_pred = scaler.inverse_transform(lstm_pred_scaled).flatten()

lstm_actual = scaler.inverse_transform(y_test_lstm.reshape(-1, 1)).flatten()

lstm_train_pred_scaled = lstm_model.predict(X_train_lstm)
lstm_train_pred = scaler.inverse_transform(lstm_train_pred_scaled).flatten()
lstm_train_actual = scaler.inverse_transform(y_train_lstm.reshape(-1, 1)).flatten()

results.append(evaluate_forecast(lstm_train_actual, lstm_train_pred, "LSTM - Train"))
results.append(evaluate_forecast(lstm_actual, lstm_pred, "LSTM - Test"))

test_df_lstm = test_df.iloc[:len(lstm_pred)].copy()
test_df_lstm['LSTM_Pred'] = lstm_pred

# %%
import pandas as pd

# Merge all three models' predictions with actual demand, matched on DateTime
merged = test_df[['DateTime', 'SYSTEM_DEMAND_MW', 'ARIMA_Pred_WF']].merge(
    test_lagged[['DateTime', 'RF_Pred']], on='DateTime', how='inner'
).merge(
    test_df_lstm[['DateTime', 'LSTM_Pred']], on='DateTime', how='inner'
)
merged = merged.rename(columns={'SYSTEM_DEMAND_MW': 'Actual'})

windows = [
    ('2022-12-12', '2022-12-16'),   # December 2022 cold snap
    ('2024-01-16', '2024-01-20'),   # January 2024 cold snap
    ('2022-07-29', '2022-08-02'),   # Summer demand trough
]

frames = []
for start, end in windows:
    mask = (merged['DateTime'] >= start) & (merged['DateTime'] <= end)
    frames.append(merged[mask])

case_study_data = pd.concat(frames)
case_study_data.to_csv('case_study_data.csv', index=False)
print(f"Rows exported: {len(case_study_data)}")
case_study_data

# %%
# Random split comparison for LSTM (windows built in time order first, then randomly split)
WINDOW = 24
full_scaled = scaler.transform(df[['SYSTEM_DEMAND_MW']])
X_all, y_all = create_sequences(full_scaled, WINDOW)

train_idx, test_idx = train_test_split(np.arange(len(X_all)), test_size=0.2, shuffle=True, random_state=42)

X_train_lstm_rand = X_all[train_idx].reshape(-1, WINDOW, 1)
X_test_lstm_rand  = X_all[test_idx].reshape(-1, WINDOW, 1)
y_train_lstm_rand = y_all[train_idx]
y_test_lstm_rand  = y_all[test_idx]

lstm_random = Sequential([
    Input(shape=(WINDOW, 1)),
    LSTM(64, activation='tanh'),
    Dense(1)
])
lstm_random.compile(optimizer='adam', loss='mse')
early_stop_r = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
lstm_random.fit(X_train_lstm_rand, y_train_lstm_rand, validation_split=0.1, epochs=15,
                batch_size=256, callbacks=[early_stop_r], verbose=0)

lstm_random_pred_scaled = lstm_random.predict(X_test_lstm_rand, verbose=0)
lstm_random_pred = scaler.inverse_transform(lstm_random_pred_scaled).flatten()
lstm_random_actual = scaler.inverse_transform(y_test_lstm_rand.reshape(-1, 1)).flatten()

results.append(evaluate_forecast(lstm_random_actual, lstm_random_pred, "LSTM - Random Split"))

# %%
# LSTM fold function for cross-validation: fits a fresh scaler and rebuilds 24-hour windows per fold, carrying the last WINDOW training points into test to avoid losing early predictions
def lstm_fold_fn(train_fold, test_fold):
    WINDOW = 24  # same window size as the main LSTM

    # Fit scaler on this fold's TRAIN ONLY - never on test, to avoid leakage
    fold_scaler = MinMaxScaler()
    train_scaled_f = fold_scaler.fit_transform(train_fold[['SYSTEM_DEMAND_MW']])
    test_scaled_f  = fold_scaler.transform(test_fold[['SYSTEM_DEMAND_MW']])

    # Carry the last WINDOW train points into test so the first test predictions
    # have a full 24h of history, same trick as the main LSTM cell
    combined_scaled_f = np.concatenate([train_scaled_f[-WINDOW:], test_scaled_f])

    X_train_f, y_train_f = create_sequences(train_scaled_f, WINDOW)
    X_test_f,  y_test_f  = create_sequences(combined_scaled_f, WINDOW)

    X_train_f = X_train_f.reshape((X_train_f.shape[0], X_train_f.shape[1], 1))
    X_test_f  = X_test_f.reshape((X_test_f.shape[0], X_test_f.shape[1], 1))

    # Fresh small model per fold - keep epochs low, CV already retrains 3x
    fold_model = Sequential([
        Input(shape=(WINDOW, 1)),
        LSTM(64, activation='tanh'),
        Dense(1)
    ])
    fold_model.compile(optimizer='adam', loss='mse')

    early_stop_f = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    fold_model.fit(
        X_train_f, y_train_f,
        validation_split=0.1,
        epochs=15,
        batch_size=256,
        callbacks=[early_stop_f],
        verbose=0
    )

    pred_scaled_f = fold_model.predict(X_test_f, verbose=0)
    y_pred = fold_scaler.inverse_transform(pred_scaled_f).flatten()
    y_true = fold_scaler.inverse_transform(y_test_f.reshape(-1, 1)).flatten()

    return y_true, y_pred

lstm_cv_df = run_timeseries_cv(df, lstm_fold_fn, label="LSTM", n_splits=3)

# %%
# ============================================================
# Build all result tables
# ============================================================
results_df = pd.DataFrame(results)

def classify_set(model_name):
    if 'Random Split' in model_name:
        return 'Random Split'
    elif 'Train' in model_name:
        return 'Train'
    else:
        return 'Test'

results_df['Set'] = results_df['Model'].apply(classify_set)
results_df['Accuracy (%)'] = 100 - results_df['MAPE']

cv_all = pd.concat([rf_cv_df, arima_cv_df, lstm_cv_df], ignore_index=True)
cv_summary = cv_all.groupby('Model').agg(
    MAE_mean=('MAE', 'mean'),   MAE_std=('MAE', 'std'),
    RMSE_mean=('RMSE', 'mean'), RMSE_std=('RMSE', 'std'),
    MAPE_mean=('MAPE', 'mean'), MAPE_std=('MAPE', 'std')
).reset_index().sort_values('RMSE_mean')
cv_summary['Accuracy (%)'] = 100 - cv_summary['MAPE_mean']

# ============================================================
# Print results grouped BY MODEL, with sub-headings per split type
# ============================================================

# Map each model family to the row-label patterns that belong to it
model_groups = {
    "RANDOM FOREST": {
        "train":  ['RF (Cal+Lag) - Train', 'RF (Calendar) - Train'],
        "test":   ['RF (Cal+Lag) - Test', 'RF (Calendar) - Test'],
        "cv":     'Random Forest',
        "random": 'RF (Cal+Lag) - Random Split',
    },
    "LSTM": {
        "train":  ['LSTM - Train'],
        "test":   ['LSTM - Test'],
        "cv":     'LSTM',
        "random": 'LSTM - Random Split',
    },
    "ARIMA": {
        "train":  ['ARIMA - Train'],
        "test":   ['ARIMA (Walk-Forward)', 'ARIMA (Blind Multi-Step)'],
        "cv":     'ARIMA',
        "random": None,  # ARIMA excluded from random-split comparison
    },
}

for model_name, groups in model_groups.items():
    print("=" * 70)
    print(model_name)
    print("=" * 70)

    # --- Train ---
    train_rows = results_df[results_df['Model'].isin(groups["train"])].drop(columns='Set')
    if not train_rows.empty:
        print("\n--- Train (in-sample fit) ---")
        print(train_rows.sort_values('RMSE').to_string(index=False))

    # --- Chronological Test ---
    test_rows = results_df[results_df['Model'].isin(groups["test"])].drop(columns='Set')
    if not test_rows.empty:
        print("\n--- Chronological Test (single 80/20 out-of-sample split) ---")
        print(test_rows.sort_values('RMSE').to_string(index=False))

    # --- TimeSeriesSplit CV ---
    cv_rows = cv_summary[cv_summary['Model'] == groups["cv"]]
    if not cv_rows.empty:
        print("\n--- TimeSeriesSplit Cross-Validation (5-fold chronological) ---")
        print(cv_rows.to_string(index=False))

    # --- Random Split ---
    if groups["random"]:
        rand_rows = results_df[results_df['Model'] == groups["random"]].drop(columns='Set')
        if not rand_rows.empty:
            print("\n--- Random Split (for comparison only — not methodologically valid) ---")
            print(rand_rows.to_string(index=False))

    print()  # blank line between model sections

# %%
# Visual comparison: Chronological Test vs CV vs Random Split, grouped by model
import matplotlib.pyplot as plt
import numpy as np

# Pull RMSE values per model for each split type
chrono_test_rmse = {
    'Random Forest\n(Cal+Lag)': results_df.loc[results_df['Model'] == 'RF (Cal+Lag) - Test', 'RMSE'].values[0],
    'LSTM': results_df.loc[results_df['Model'] == 'LSTM - Test', 'RMSE'].values[0],
    'ARIMA': results_df.loc[results_df['Model'] == 'ARIMA (Walk-Forward)', 'RMSE'].values[0],
}

cv_mean_rmse = {
    'Random Forest\n(Cal+Lag)': cv_summary.loc[cv_summary['Model'] == 'Random Forest', 'RMSE_mean'].values[0],
    'LSTM': cv_summary.loc[cv_summary['Model'] == 'LSTM', 'RMSE_mean'].values[0],
    'ARIMA': cv_summary.loc[cv_summary['Model'] == 'ARIMA', 'RMSE_mean'].values[0],
}
cv_std_rmse = {
    'Random Forest\n(Cal+Lag)': cv_summary.loc[cv_summary['Model'] == 'Random Forest', 'RMSE_std'].values[0],
    'LSTM': cv_summary.loc[cv_summary['Model'] == 'LSTM', 'RMSE_std'].values[0],
    'ARIMA': cv_summary.loc[cv_summary['Model'] == 'ARIMA', 'RMSE_std'].values[0],
}

# Random split only exists for RF and LSTM (ARIMA excluded — see Part 3 note)
random_split_rmse = {
    'Random Forest\n(Cal+Lag)': results_df.loc[results_df['Model'] == 'RF (Cal+Lag) - Random Split', 'RMSE'].values[0],
    'LSTM': results_df.loc[results_df['Model'] == 'LSTM - Random Split', 'RMSE'].values[0],
    'ARIMA': None,  # not applicable
}

models = list(chrono_test_rmse.keys())
x = np.arange(len(models))
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))

bars1 = ax.bar(x - width, [chrono_test_rmse[m] for m in models], width,
                label='Chronological Test (80/20 Split)', color='#4C72B0')
bars2 = ax.bar(x, [cv_mean_rmse[m] for m in models], width,
                yerr=[cv_std_rmse[m] for m in models], capsize=5,
                label='TimeSeriesSplit CV (mean ± std)', color='#DD8452')
bars3 = ax.bar(x + width, [random_split_rmse[m] if random_split_rmse[m] is not None else 0 for m in models],
                width, label='Random Split (comparison only)', color='#55A868')

ax.set_ylabel('RMSE (MW)', fontsize=12)
ax.set_title('Model Accuracy by Split Method (Grouped by Model)', fontsize=13, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(models, fontsize=11)
ax.legend(fontsize=10)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

for bars in [bars1, bars2, bars3]:
    for bar in bars:
        height = bar.get_height()
        if height > 0:  # skip the empty ARIMA random-split bar
            ax.annotate(f'{height:.1f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 8), textcoords="offset points", ha='center', fontsize=9)

plt.tight_layout()
plt.savefig('rmse_comparison_chart.png', dpi=200, bbox_inches='tight')
plt.show()
